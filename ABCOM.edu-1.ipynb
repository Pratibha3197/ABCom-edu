# %% [markdown]
# ### Time Series Analysis

# %% [markdown]
# ### Introduction
#
# **A) When someone talks about timeseries then a person with no background of statistics is get confused what excatly time series is?** so, It is a series of observations taken at specified time intervals usually equal intervals. Analysis of the series helps us to predict future values based on previous observed values. In Time series, we have only 2 variables, time & the variable we want to forecast.
#
# **B) Time series data can be analysed in order to extract meaningful statistics and other charecteristsics. It's used in atleast the 4 scenarios:**
#             a) Business Forecasting
#             b) Understand past behavior
#             c) Plan the future
#             d) Evaluate current accomplishment
#
# **C) We don't need to apply Time series in atleast the following 2 cases:**
#     a) The dependant variable(y) (that is supposed to vary with time) is constant. Eq: y=f(x)=4, a line parallel to x-axis(time) will always remain the same.
#     b) The dependant variable(y) represent values that can be denoted as a mathematical function. Eq: sin(x), log(x), Polynomials etc. Thus, we can directly get value at some time using the function itself. No need of forecasting.
#
# **D) There are 4 components:**
#     a) Trend - Upward & downward movement of the data with time over a large period of time. Eq: Appreciation of Dollar vs rupee.
#     b) Seasonality - seasonal variances. Eq: Ice cream sales increases in Summer only
#     c) Noise or Irregularity - Spikes & troughs at random intervals
#     d) Cyclicity - behavior that repeats itself after large interval of time, like months, years etc.
#
#
# **E) Before applying any statistical model on a Time Series, the series has to be staionary, which means that, over different time  periods, **
#     a) It should have constant mean.
#     b) It should have constant variance or standard deviation.
#     c) Auto-covariance should not depend on time.
#
# Trend & Seasonality are two reasons why a Time Series is not stationaru & hence need to be corrected.
#
#
# **F) Time series has to be stationary because of the following reasons: **
#     a) If a TS has a particular behavior over a time interval, then there's a high probability that over a different interval, it will have same behavior, provided TS is stationary. This helps in forecasting accurately.
#     b) Theories & Mathematical formulas ae more mature & easier to apply for as TS which is stationary.
#
# **G) There are 2 ways to check for Stationarity of a TS:**
#     a) Rolling Statistics - Plot the moving avg or moving standard deviation to see if it varies with time. Its a visual technique.
#     b) ADCF Test - Augmented Dickey–Fuller test is used to gives us various values that can help in identifying stationarity. The Null hypothesis says that a TS is non-stationary. It comprises of a **Test Statistics** & some **critical values** for some confidence levels. If the Test statistics is less than the critical values, we can reject the null hypothesis & say that the series is stationary. THE ADCF test also gives us a **p-value**. Acc to the null hypothesis, lower values of p is better.
#
# **H) ARIMA**
#   ARIMA(Auto Regressive Integrated Moving Average) is a combination of 2 models AR(Auto Regressive) & MA(Moving Average). It has 3 hyperparameters - P(auto regressive lags),d(order of differentiation),Q(moving avg.) which respectively comes from the AR, I & MA components. The AR part is correlation between prev & current time periods. To smooth out the noise, the MA part is used. The I part binds together the AR & MA parts.
#
# To find value of P & Q for ARIMA we need to take help of ACF(Auto Correlation Function) & PACF(Partial Auto Correlation Function) plots.
# ACF & PACF graphs are used to find value of P & Q for ARIMA. We need to check, for which value in x-axis, graph line drops to 0 in y-axis for 1st time.
# From PACF(at y=0), get P
# From ACF(at y=0), get Q
#
# **I) ADCF test**
# A. In statistics and econometrics, an augmented Dickey–Fuller test (ADF) tests the null hypothesis that a unit root is present in a time series sample. The alternative hypothesis is different depending on which version of the test is used, but is usually stationarity or trend-stationarity. It is an augmented version of the Dickey–Fuller test for a larger and more complicated set of time series models.
#
# The augmented Dickey–Fuller (ADF) statistic, used in the test, is a negative number. The more negative it is, the stronger the rejection of the hypothesis that there is a unit root at some level of confidence.
#
# p value(0<=p<=1) should be as low as possible. Critical values at different confidence intervals should be close to the Test statistics value.
#
# **J) Exponential Smoothing**
# A. *Exponential smoothing* is a rule of thumb technique for smoothing time series data using the exponential window function. Whereas in the simple moving average the past observations are weighted equally, exponential functions are used to assign exponentially decreasing weights over time. It is an easily learned and easily applied procedure for making some determination based on prior assumptions by the user, such as seasonality. Exponential smoothing is often used for analysis of time-series data.
#
# The raw data sequence is often represented by ${x_{t}}$ beginning at time $t=0$, and the output of the exponential smoothing algorithm is commonly written as ${s_{t}}$, which may be regarded as a best estimate of what the next value of $x$ will be. When the sequence of observations begins at time $t=0$, the simplest form of exponential smoothing is given by the formulas:
#
# $s_{0} = x_{0}$
# $s_{t} = α*x_{t} + (1-α)*s_{t-1}$  , $t>0$
#
# where $α$ is the smoothing factor, and $0<α<1$.
#
# **K) Exponential decay**
# A. A quantity is subject to exponential decay if it decreases at a rate proportional to its current value. Symbolically, this process can be expressed by the following differential equation, where N is the quantity and λ (lambda) is a positive rate called the exponential decay constant:
#
# $dN/dt = -λN$
#
# The solution to this equation (see derivation below) is:
# $N(t) = N_{0}*e^{-λt}$
#
# where N(t) is the quantity at time t, and N0 = N(0) is the initial quantity, i.e. the quantity at time t = 0.
#
# **Half Life** is the time required for the decaying quantity to fall to one half of its initial value. It is denoted by $t_{1/2}$. The half-life can be written in terms of the decay constant as:
#
# $t_{1/2} = ln(2)/λ$

# %% [markdown]
# **DataSource:** Kaggle(Daily Delhi Climate)
# There are two different datasets: train and test datasets both have the same structure.This file contains weather data collected in the city of Delhi from the period of 4 years (from 2013 to 2017). It can be used for the purpose of training. This is purely academic dataset and is developed as a part of Data Analytics course of 2019 at PES University, Bangalore.
# There are 5 columns in the data. It's name and descriptions are as follows:
#
# **1)date:** Date of format YYYY-MM-DD
#
# **2)meantemp:** Mean temperature averaged out from multiple 3 hour intervals in a day.
#
# **3)humidity:** Humidity value for the day (units are frams of water vapor per cubic meter volume of air).
#
# **4)wind_speed:** Wind speed measured in kmph.
#
# **5)meanpressure:** Pressure reading of weather (measure in atm)
#
#
# ### Objective :

# %% [markdown]
# ### Import Necessary Libraries and Datasets

# %%
from datetime import datetime
import numpy as np             #for numerical computations like log,exp,sqrt etc
import pandas as pd            #for reading & storing data, pre-processing
import matplotlib.pylab as plt #for visualization
#for making sure matplotlib plots are generated in Jupyter notebook itself
# %matplotlib inline             
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10, 6

# %%
data_train=pd.read_csv(r"C:\Users\hp\Downloads\DailyDelhiClimateTrain.csv",index_col='date',parse_dates=True,squeeze=True)

# %%
data_train.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
data_train.shape
# Out:
# (1462, 4)

# %%
data_test=pd.read_csv(r"C:\Users\hp\Downloads\DailyDelhiClimateTest.csv",index_col='date',parse_dates=True,squeeze=True)

# %%
data_test.shape
# Out:
# (114, 4)

# %% [markdown]
# **Data Preprocess and Visualization**

# %%
print("Train Data: ",data_train.isnull().sum())
print("Train Data: ",data_test.isnull().sum())
# Out:
# Train Data:  meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64
# Train Data:  meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %% [markdown]
# To make Analysis easier, i have to concatenate both data sets and just work with a single dataframe

# %%
data=pd.concat([data_train,data_test])

# %%
data
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000
# ...               ...        ...         ...           ...
# 2017-04-20  34.500000  27.500000    5.562500    998.625000
# 2017-04-21  34.250000  39.375000    6.962500    999.875000
# 2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [1576 rows x 4 columns]

# %%
data.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1576.000000  1576.000000  1576.000000   1576.000000
# mean     25.221918    60.445229     6.899262   1010.593178
# std       7.345014    16.979994     4.510725    175.242704
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.500000    49.750000     3.700000   1001.875000
# 50%      27.166667    62.440476     6.363571   1009.055556
# 75%      31.142857    72.125000     9.262500   1015.200000
# max      38.714286   100.000000    42.220000   7679.333333

# %% [markdown]
# From the plot below, we can see that there is a Trend compoenent in the series. Hence, we now check for stationarity of the data

# %%
data.plot(subplots=True, figsize=(14,6))
plt.show()

# %% [markdown]
# ### Checking Stationarity
# Two methods are there for checking stationarity present in the data:
#
# **1) Rolling Statistics**
#
# **2)Augumented Dickey Fuller test**

# %%
#Determine rolling statistics
rolmean = data.rolling(window=12).mean() #window size 12 denotes 12 months, giving rolling mean at yearly level
rolstd = data.rolling(window=12).std()
print(rolmean,rolstd)
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01        NaN        NaN         NaN           NaN
# 2013-01-02        NaN        NaN         NaN           NaN
# 2013-01-03        NaN        NaN         NaN           NaN
# 2013-01-04        NaN        NaN         NaN           NaN
# 2013-01-05        NaN        NaN         NaN           NaN
# ...               ...        ...         ...           ...
# 2017-04-20  30.868882  27.761409    8.383598   1004.622851
# 2017-04-21  31.462632  29.282242    7.786723   1003.727017
# 2017-04-22  31.882870  31.071528    6.918032   1003.146065
# 2017-04-23  32.184954  31.884028    6.455532   1002.802315
# 2017-04-24  32.414120  31.979266    6.678003   1002.657970
#
# [1576 rows x 4 columns]             meantemp  humidity  wind_speed  meanpressure
# date
# 2013-01-01       NaN       NaN         NaN           NaN
# 2013-01-02       NaN       NaN         NaN           NaN
# ...

# %%
#Plot rolling statistics
orig = plt.plot(data, color='blue', label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %% [markdown]
# From the above graph, we see that rolling mean and rolling standard deviation is fairly constant with time. For our time series to be stationary, we need to ensure that both the rolling statistics ie: mean & std. dev. remain time invariant or constant with time. Thus the curves for both of them have to be parallel to the x-axis.Here,we can say that our time series data is stationary.

# %%
df_monthly = pd.DataFrame(data,columns=['meantemp','humidity','wind_speed','meanpressure']).resample('MS').mean()
df_monthly.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  12.074770  73.028802    4.833913   1017.847734
# 2013-02-01  16.867560  71.938563    7.474090   1015.946003
# 2013-03-01  22.814209  57.417243    8.757270   1011.733909
# 2013-04-01  28.895119  34.612103    8.046385   1006.292341
# 2013-05-01  33.776767  28.938249    8.943452    999.924194

# %%
df_monthly.plot(figsize=(14,6))
plt.show()

# %% [markdown]
# Now, we'll perform ADCF test, to check stationarity

# %%
#Perform Augmented Dickey–Fuller test:
print('Results of Dickey Fuller Test for meantemp:')
dftest = adfuller(df_monthly['meantemp'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
print('\n')
print('Results of Dickey Fuller Test for humidity:')
dftest = adfuller(df_monthly['humidity'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
print('\n')
print('Results of Dickey Fuller Test for wind speed:')
dftest = adfuller(df_monthly['wind_speed'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
print('\n')
print('Results of Dickey Fuller Test for humidity:')
dftest = adfuller(df_monthly['humidity'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
    
print(dfoutput)
# Out:
# Results of Dickey Fuller Test for meantemp:
# Test Statistic                 -0.518411
# p-value                         0.888373
# #Lags Used                     10.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64
#
#
# Results of Dickey Fuller Test for humidity:
# Test Statistic                 -1.309834
# p-value                         0.624661
# #Lags Used                     11.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64
#
#
# Results of Dickey Fuller Test for wind speed:
# Test Statistic                 -5.010225
# p-value                         0.000021
# #Lags Used                      5.000000
# Number of Observations Used    46.000000
# Critical Value (1%)            -3.581258
# ...

# %% [markdown]
# For a Time series to be stationary, its ADCF test should have:
# 1. p-value to be low (according to the null hypothesis)
# 2. The critical values at 1%,5%,10% confidence intervals should be as close as possible to the Test Statistics
#
# From the above ADCF test result, we see that p-value(at max can be 1.0) is very large. Also critical values are no where close to the Test Statistics. Hence, we can safely say that **our Time Series at the moment is stationary**

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize']=18,8
decomposition=sm.tsa.seasonal_decompose(df_monthly['meantemp'],model='additive')
fig=decomposition.plot()
plt.legend(loc='best')

plt.tight_layout()
plt.legend(loc='best')
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
decomposition=sm.tsa.seasonal_decompose(df_monthly['wind_speed'],model='additive')
fig=decomposition.plot()
plt.legend(loc='best')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
decomposition=sm.tsa.seasonal_decompose(df_monthly['meanpressure'],model='additive')
fig=decomposition.plot()
plt.legend(loc='best')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
decomposition=sm.tsa.seasonal_decompose(df_monthly['humidity'],model='additive')
fig=decomposition.plot()
plt.legend(loc='best')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Data Transformation to achieve Stationarity <a name="data-transform"></a>
#
# There are a couple of ways to achieve stationarity through data transformation like taking $log_{10}$,$log_{e}$, square, square root, cube, cube root, exponential decay, time shift and so on ...
#
# Lets start of with log transformations. Our objective is to remove the trend component. Hence,  flatter curves( ie: paralle to x-axis) for time series and rolling mean after taking log would say that our data transformation did a good job.

# %% [markdown]
# ### Log Scale Transformation  <a name="log"></a>

# %%
#Estimating trend
Data_logScale = np.log(data)
plt.plot(Data_logScale)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# ...

# %%
#The below transformation is required to make series stationary
movingAverage = Data_logScale.rolling(window=12).mean()
movingSTD = Data_logScale.rolling(window=12).std()
plt.plot(Data_logScale)
plt.plot(movingAverage, color='red')

# %% [markdown]
# We know from above graph that both the Time series with log scale as well as its moving average have a trend component. Thus we can apply a elementary intuition: subtraction one from the other should remove the trend component of both. Its like:
#
# $log scale L = stationary part(L1) + trend(LT)$
# $moving avg of log scale A = stationary part(A1) + trend(AT)$
# $result series R = L - A = (L1+LT) - (A1+AT) = (L1-A1) + (LT-AT)$
#
# Since, L & A are series & it moving avg, their trend will be more or less same, Hence
# LT-AT nearly equals to 0
#
# Thus trend component will be almost removed. And we have,
#
# $R = L1 - A1$, our final non-trend curve

# %%
meantemp_1= df_monthly - df_monthly.rolling(15).mean()
meantemp_1= meantemp_1.dropna()
meantemp_1.head()
# Out:
#             meantemp   humidity  wind_speed  meanpressure
# date
# 2014-03-01 -1.596912  -2.792581    0.380854      4.013782
# 2014-04-01  3.802532 -22.300504    1.856541     -0.201674
# 2014-05-01  6.180531 -19.202661    1.490967     -4.175474
# 2014-06-01  8.748726 -17.287356    2.935397    -10.113623
# 2014-07-01  5.802786   1.001727    0.387256     -8.078093

# %%
datasetLogScaleMinusMovingAverage = Data_logScale - movingAverage
datasetLogScaleMinusMovingAverage.head(12)

#Remove NAN values
datasetLogScaleMinusMovingAverage.dropna(inplace=True)
datasetLogScaleMinusMovingAverage.head(10)
# Out:
#             meantemp  humidity  wind_speed  meanpressure
# date
# 2013-01-13  0.496459  0.046433   -0.078638     -0.003657
# 2013-01-14  0.240507  0.209501   -1.964062     -0.001633
# 2013-01-15  0.317331  0.020888   -1.937308     -0.000723
# 2013-01-28  0.146183 -0.230947   -0.320498     -0.001509
# 2013-01-29  0.110203 -0.056720   -0.413744     -0.002762
# 2013-01-30  0.145931  0.038245   -1.354969     -0.001826
# 2013-01-31  0.220517 -0.019787   -0.268105     -0.001026
# 2013-02-01  0.179007  0.089666   -0.444187     -0.003035
# 2013-02-02  0.165508  0.149790   -0.914807     -0.001595
# 2013-02-03  0.212335 -0.002044   -0.537624     -0.002890

# %%
def test_stationarity(timeseries):
    
    #Determine rolling statistics
    movingAverage = timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()
    
    #Plot rolling statistics
    orig = plt.plot(timeseries, color='blue', label='Original')
    mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
    std = plt.plot(movingSTD, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey–Fuller test:
    print('Results of Dickey Fuller Test for meantemp:')
    dftest = adfuller(df_monthly['meantemp'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
    print('\n')
    print('Results of Dickey Fuller Test for humidity:')
    dftest = adfuller(df_monthly['humidity'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
    print('\n')
    print('Results of Dickey Fuller Test for wind_speed:')
    dftest = adfuller(df_monthly['wind_speed'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    
    print('\n')
    print('Results of Dickey Fuller Test for meanpressure:')
    dftest = adfuller(df_monthly['meanpressure'], autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(datasetLogScaleMinusMovingAverage)
# Out:
# Results of Dickey Fuller Test for meantemp:
# Test Statistic                 -0.518411
# p-value                         0.888373
# #Lags Used                     10.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64
#
#
# Results of Dickey Fuller Test for humidity:
# Test Statistic                 -1.309834
# p-value                         0.624661
# #Lags Used                     11.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64
#
#
# Results of Dickey Fuller Test for wind_speed:
# Test Statistic                 -5.010225
# p-value                         0.000021
# #Lags Used                      5.000000
# Number of Observations Used    46.000000
# Critical Value (1%)            -3.581258
# ...

# %% [markdown]
# ### Exponential Decay Transformation   <a name="exp"></a>

# %%
exponentialDecayWeightedAverage = Data_logScale.ewm(halflife=12, min_periods=0, adjust=True).mean()
plt.plot(Data_logScale)
plt.plot(exponentialDecayWeightedAverage, color='red')

# %%
datasetLogScaleMinusExponentialMovingAverage = Data_logScale - exponentialDecayWeightedAverage
test_stationarity(datasetLogScaleMinusExponentialMovingAverage)
# Out:
# Results of Dickey Fuller Test for meantemp:
# Test Statistic                 -0.518411
# p-value                         0.888373
# #Lags Used                     10.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64
#
#
# Results of Dickey Fuller Test for humidity:
# Test Statistic                 -1.309834
# p-value                         0.624661
# #Lags Used                     11.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64
#
#
# Results of Dickey Fuller Test for wind_speed:
# Test Statistic                 -5.010225
# p-value                         0.000021
# #Lags Used                      5.000000
# Number of Observations Used    46.000000
# Critical Value (1%)            -3.581258
# ...

# %% [markdown]
# ### Time Shift Transformation  <a name="shift"></a>
#
# lets try out the simple time shift technique, which is simply:
#
# Given a set of observation on the time series:
# $ x0, x1, x2, x3, .... xn $
#
# The shifted values will be:
# $ null, x0, x1, x2,.... xn $                             <---- basically all xi's shifted by 1 pos to right
#
# Thus, the time series with time shifted values are:
# $ null, (x1-x0), (x2-x1), (x3-x2), (x4-x3),.... (xn-x_{n-1}) $

# %%
datasetLogDiffShifting = Data_logScale - Data_logScale.shift()
plt.plot(datasetLogDiffShifting)

# %%
datasetLogDiffShifting.dropna(inplace=True)
test_stationarity(datasetLogDiffShifting)
# Out:
# Results of Dickey Fuller Test for meantemp:
# Test Statistic                 -0.518411
# p-value                         0.888373
# #Lags Used                     10.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64
#
#
# Results of Dickey Fuller Test for humidity:
# Test Statistic                 -1.309834
# p-value                         0.624661
# #Lags Used                     11.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64
#
#
# Results of Dickey Fuller Test for wind_speed:
# Test Statistic                 -5.010225
# p-value                         0.000021
# #Lags Used                      5.000000
# Number of Observations Used    46.000000
# Critical Value (1%)            -3.581258
# ...

# %% [markdown]
# The ADCF test shows us that:
# 1. p-value of 0.07 is not as good as 0.005 of exponential decay.
# 2. Test Statistic value not as close to the critical values as that for exponential decay.

# %%
Data_logScale.isnull().sum()
# Out:
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    1
# dtype: int64

# %%
Data_logScale.dropna(inplace=True)
Data_logScale.head()
# Out:
#             meantemp  humidity  wind_speed  meanpressure
# date
# 2013-01-01  2.302585  4.436752        -inf      6.923300
# 2013-01-02  2.001480  4.521789    1.091923      6.925399
# 2013-01-03  1.969441  4.465908    1.533277      6.926250
# 2013-01-04  2.159484  4.267364    0.209721      6.924776
# 2013-01-05  1.791759  4.463991    1.308333      6.924121

# %%
Data_logScale.isnull().sum()
# Out:
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %%
residual=decomposition.resid

# %%
#there can be cases where an observation simply consisted of trend & seasonality. In that case, there won't be 
#any residual component & that would be a null or NaN. Hence, we also remove such cases.
decomposedLogData = residual
decomposedLogData.dropna(inplace=True)
test_stationarity(decomposedLogData)
# Out:
# Results of Dickey Fuller Test for meantemp:
# Test Statistic                 -0.518411
# p-value                         0.888373
# #Lags Used                     10.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64
#
#
# Results of Dickey Fuller Test for humidity:
# Test Statistic                 -1.309834
# p-value                         0.624661
# #Lags Used                     11.000000
# Number of Observations Used    40.000000
# Critical Value (1%)            -3.605565
# Critical Value (5%)            -2.937069
# Critical Value (10%)           -2.606986
# dtype: float64
#
#
# Results of Dickey Fuller Test for wind_speed:
# Test Statistic                 -5.010225
# p-value                         0.000021
# #Lags Used                      5.000000
# Number of Observations Used    46.000000
# Critical Value (1%)            -3.581258
# ...

# %% [markdown]
# An **ARIMA** model is a class of statistical models for analyzing and forecasting time series data. ARIMA model is one model for non-stationarity. It assumes that the data becomes stationary after differencing.
#
# **ARIMA** is an acronym that stands for AutoRegressive Integrated Moving Average. It is a generalization of the simpler AutoRegressive Moving Average and adds the notion of integration.
#
#
#
# These acronyms describe it pretty well:
# 1. **AR**: Autoregression. A model that uses the dependent relationship between an observation and some number of lagged observations.
# 2.**I**: Integrated. The use of differencing of raw observations (e.g. subtracting an observation from an observation at the previous time step) in order to make the time series stationary.
# 3. **MA**: Moving Average. A model that uses the dependency between an observation and a residual error from a moving average model applied to lagged observations.
#
#
#
# Each of these components are explicitly specified in the model as a parameter. A standard notation is used of ARIMA(p,d,q) where the parameters are substituted with integer values to quickly indicate the specific ARIMA model being used.
#
# Parameters are defined as follows:
#
# 1. **p**: The number of lag observations included in the model, also called the lag order.
# 2. **d**: The number of times that the raw observations are differenced, also called the degree of differencing.
# 3. **q**: The size of the moving average window, also called the order of moving average.
#
#
# Now we need to make model selection, with help of :
# * Autocorrelation Function (ACF). The plot summarizes the correlation of an observation with lag values. The x-axis shows the lag and the y-axis shows the correlation coefficient between -1 and 1 for negative and positive correlation.
# * Partial Autocorrelation Function (PACF). The plot summarizes the correlations for an observation with lag values that is not accounted for by prior lagged observations.
# We can get a basic picture of the parameter interval, and using this heuristic we can  with help of AIC- Akaike information criterion decide which are the best p,q,d for ARIMA.
#
# A problem with ARIMA is that it does not support seasonal data.That is a time series with a repeating cycle. ARIMA expects data that is either not seasonal or has the seasonal component removed
#
# ### SARIMA:
# SARIMA is Seasonal AUtoregressive Integrated Moving Average,is an extension of ARIMA that explicitly supports univariate time series data with a seasonal component. It adds three new hyperparameters to specify the autoregressive(AR), differencing(I), and moving average(MA) for the seasonal component of the series,as well as an additional parameter for the period of seasonality.
# There are four seasonal elements that are not part of ARIMA that must be configured; they are:
#
# **P:** Seasonal autoregressive order
#
# **D:** Seasonal difference order
#
# **Q:** Seasonal moving average order
#
# **m:** The number of time steps for a single seasonal period.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, ax = plt.subplots(figsize=(12,8))
plot_acf(df_monthly['meantemp'], lags=25, zero=False, ax=ax)
plt.title('Autocorrelation function for mean tempreture')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
plot_acf(df_monthly['humidity'], lags=25, zero=False, ax=ax)
plt.title('Autocorrelation function for humidity')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
plot_acf(df_monthly['wind_speed'], lags=25, zero=False, ax=ax)
plt.title('Autocorrelation function for wind speed')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))
plot_acf(df_monthly['meanpressure'], lags=25, zero=False, ax=ax)
plt.title('Autocorrelation function for mean pressure')
plt.show()

# %%
#Choosing SARIMA order:
# Create the figure 
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))

# Plot the ACF on ax1
plot_acf(df_monthly['meantemp'], lags=11, zero=False, ax=ax1)

# Plot the PACF on ax2
plot_pacf(df_monthly['meantemp'], lags=11, zero=False, ax=ax2)
plt.show()

# %%
#Choosing SARIMA order:
# Create the figure 
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))


# Plot the ACF on ax1
plot_acf(df_monthly['humidity'], lags=11, zero=False, ax=ax1)

# Plot the PACF on ax2
plot_pacf(df_monthly['humidity'], lags=11, zero=False, ax=ax2)

plt.show()

# %%
#Choosing SARIMA order:
# Create the figure 
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))

# Plot the ACF on ax1
plot_acf(df_monthly['wind_speed'], lags=11, zero=False, ax=ax1)

# Plot the PACF on ax2
plot_pacf(df_monthly['wind_speed'], lags=11, zero=False, ax=ax2)

plt.show()

# %%
#Choosing SARIMA order:
# Create the figure 
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))
# Plot the ACF on ax1
plot_acf(df_monthly['meanpressure'], lags=11, zero=False, ax=ax1)

# Plot the PACF on ax2
plot_pacf(df_monthly['meanpressure'], lags=11, zero=False, ax=ax2)

plt.show()

# %%
df_monthly_diff =df_monthly.diff(1).diff(12).dropna()
df_monthly_diff.head()
# Out:
#             meantemp   humidity  wind_speed  meanpressure
# date
# 2014-02-01 -2.477814 -10.146245   -1.798525     -2.571771
# 2014-03-01 -0.100143   3.508956   -0.561448      3.039859
# 2014-04-01  0.384105   1.139145    2.455552      0.598327
# 2014-05-01 -1.534451   6.758628   -1.189143      1.573716
# 2014-06-01  4.661197 -28.887398    0.884219     -4.425343

# %%
lags= [11, 22, 33]
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))
plot_acf(df_monthly_diff['meantemp'], lags=lags, zero=False, ax=ax1)
plot_pacf(df_monthly_diff['meantemp'], lags=lags, zero=False, ax=ax2)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
lags= [11, 22, 33]
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))
plot_acf(df_monthly_diff['humidity'], lags=lags, zero=False, ax=ax1)
plot_pacf(df_monthly_diff['humidity'], lags=lags, zero=False, ax=ax2)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
lags= [11, 22, 33]
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))
plot_acf(df_monthly_diff['wind_speed'], lags=lags, zero=False, ax=ax1)
plot_pacf(df_monthly_diff['wind_speed'], lags=lags, zero=False, ax=ax2)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
lags= [11, 22, 33]
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(8,6))
plot_acf(df_monthly_diff['meanpressure'], lags=lags, zero=False, ax=ax1)
plot_pacf(df_monthly_diff['meanpressure'], lags=lags, zero=False, ax=ax2)
plt.show()
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
#Choosing Model Orders
from pmdarima.arima import auto_arima
print('Model for monthly mean tempreture')
print('\n')
model11 = auto_arima(df_monthly['meantemp'],
                      seasonal=True, m=12,
                      d=0, D=1, 
                 	  max_p=2, max_q=2,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True)

print(model11.summary())
# Out:
# Model for monthly mean tempreture
#
#
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=2.16 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=157.304, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=140.485, Time=0.23 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=160.323, Time=0.06 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=154.263, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=133.740, Time=0.55 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=2.28 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=136.499, Time=0.46 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=135.642, Time=0.75 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=135.695, Time=0.94 sec
#  ARIMA(0,0,1)(2,1,0)[12] intercept   : AIC=135.072, Time=0.47 sec
# ...

# %%
#Choosing Model Orders
print('Model for monthly humidity')
print('\n')
model12 = auto_arima(df_monthly['humidity'],
                      seasonal=True, m=12,
                      d=0, D=1, 
                 	  max_p=2, max_q=2,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True)

print(model12.summary())
# Out:
# Model for monthly humidity
#
#
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=1.51 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=290.590, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=281.040, Time=0.23 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=289.633, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=289.959, Time=0.06 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=278.223, Time=0.72 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=2.18 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=280.006, Time=0.41 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=280.144, Time=0.76 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=280.173, Time=0.75 sec
#  ARIMA(0,0,1)(2,1,0)[12] intercept   : AIC=279.138, Time=0.58 sec
# ...

# %%
#Choosing Model Orders
from pmdarima.arima import auto_arima
print('Model for monthly wind speed')
print('\n')

model13 = auto_arima(df_monthly['wind_speed'],
                      seasonal=True, m=12,
                      d=0, D=1, 
                 	  max_p=2, max_q=2,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True)

print(model13.summary())
# Out:
# Model for monthly wind speed
#
#
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=1.60 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=139.002, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=133.926, Time=0.20 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=138.251, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=137.020, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=135.284, Time=0.51 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=132.661, Time=0.23 sec
#  ARIMA(1,0,0)(0,1,2)[12] intercept   : AIC=inf, Time=1.89 sec
#  ARIMA(1,0,0)(1,1,2)[12] intercept   : AIC=inf, Time=2.61 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=133.446, Time=0.33 sec
# ...

# %%
#Choosing Model Orders
print('Model for monthly mean pressure')
print('\n')
model14 = auto_arima(df_monthly['meanpressure'],
                      seasonal=True, m=12,
                      d=0, D=1, 
                 	  max_p=2, max_q=2,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True)

print(model14.summary())
# Out:
# Model for monthly mean pressure
#
#
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=1.80 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=429.723, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=419.014, Time=0.42 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=427.841, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=431.721, Time=0.09 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=419.353, Time=1.03 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=1.17 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=421.774, Time=2.84 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=417.020, Time=0.34 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=417.363, Time=0.54 sec
#  ARIMA(0,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.77 sec
# ...

# %% [markdown]
# **1)For Mean Temperature SARIMAX(1, 0, 0)x(2, 1, 0, 12)performs better than other model of orders and has low AIC value**
#
# **2)For Humidity SARIMAX(1, 0, 0)x(2, 1, 0, 12) performs better than other model of orders and has low AIC value**
#
# **3)For Wind Speed SARIMAX(1, 0, 0)x(0, 1, [1], 12) performs better than other model of orders and has low AIC value**
#
# **4)For Mean Pressure SARIMAX(2, 0, 2)x(2, 1, 0, 12) performs better than other model of orders and has low AIC value**

# %%
#Split train set and test set from Train Dataset and fit our model
train= df_monthly[:-13]
test= df_monthly[-13:]

print(train.shape, test)
# Out:
# (39, 4)              meantemp   humidity  wind_speed  meanpressure
# date
# 2016-04-01  32.550029  29.244164    9.687357   1005.738005
# 2016-05-01  34.728726  38.958726    9.506423   1001.847837
# 2016-06-01  34.946836  51.759739    9.052079    998.050478
# 2016-07-01  30.875806  75.429839    6.207018    997.788172
# 2016-08-01  31.116578  72.993345    7.168392    934.847045
# 2016-09-01  31.479768  61.011111    7.508029   1016.249791
# 2016-10-01  28.961680  56.218619    7.291021   1009.202900
# 2016-11-01  22.957378  54.051350    5.993723    992.071066
# 2016-12-01  17.672565  68.840384    6.132705   1016.290993
# 2017-01-01  15.532408  77.901123    6.939139    987.681449
# 2017-02-01  18.349981  64.375728    7.566294   1015.574251
# 2017-03-01  23.753760  48.009694    8.884385   1010.469641
# 2017-04-01  30.753663  30.408185    9.128446   1004.564831

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
#Fit Sarimax model to Train set
model1= SARIMAX(train['meantemp'], order=(1,0,0), seasonal_order=(2,1,0,12))
results1=model1.fit()
print(results1.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                           meantemp   No. Observations:                   39
# Model:             SARIMAX(1, 0, 0)x(2, 1, 0, 12)   Log Likelihood                 -47.653
# Date:                            Thu, 17 Sep 2020   AIC                            103.306
# Time:                                    13:59:03   BIC                            108.489
# Sample:                                01-01-2013   HQIC                           104.847
#                                      - 03-01-2016
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5075      0.167      3.031      0.002       0.179       0.836
# ar.S.L12      -0.8473      0.298     -2.839      0.005      -1.432      -0.262
# ...

# %%
#Fit Sarimax model to Train set
model2= SARIMAX(train['humidity'], order=(1,0,0), seasonal_order=(2,1,0,12))
results2=model2.fit()
print(results2.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                           humidity   No. Observations:                   39
# Model:             SARIMAX(1, 0, 0)x(2, 1, 0, 12)   Log Likelihood                 -93.453
# Date:                            Thu, 17 Sep 2020   AIC                            194.906
# Time:                                    13:59:46   BIC                            200.089
# Sample:                                01-01-2013   HQIC                           196.447
#                                      - 03-01-2016
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3529      0.207      1.703      0.088      -0.053       0.759
# ar.S.L12      -0.8095      0.345     -2.348      0.019      -1.485      -0.134
# ...

# %%
#Fit Sarimax model to Train set
model3= SARIMAX(train['wind_speed'], order=(1,0,0), seasonal_order=(0,1,[1],12))
results3=model3.fit()
print(results3.summary())
# Out:
#                                       SARIMAX Results
# ...
# Dep. Variable:                           wind_speed   No. Observations:                   39
# Model:             SARIMAX(1, 0, 0)x(0, 1, [1], 12)   Log Likelihood                 -34.894
# Date:                              Thu, 17 Sep 2020   AIC                             75.789
# Time:                                      14:00:38   BIC                             79.676
# Sample:                                  01-01-2013   HQIC                            76.945
#                                        - 03-01-2016
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1662      0.163     -1.017      0.309      -0.486       0.154
# ma.S.L12      -0.0359      0.385     -0.093      0.926      -0.791       0.719
# ...

# %%
#Fit Sarimax model to Train set
model4= SARIMAX(train['meanpressure'], order=(2,0,2), seasonal_order=(2,1,0,12))
results4=model4.fit()
print(results4.summary())
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\hp\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:994: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
#                                       SARIMAX Results
# ...
# Dep. Variable:                        meanpressure   No. Observations:                   39
# Model:             SARIMAX(2, 0, 2)x(2, 1, [], 12)   Log Likelihood                -138.580
# Date:                             Thu, 17 Sep 2020   AIC                            291.159
# Time:                                     14:01:15   BIC                            300.230
# ...

# %% [markdown]
# Here in all 4 cases, Prob(Q) is >0.05, so we failed to reject Null Hypothesis that the residuals are uncorrelated. Prob(JB) >0.05, so we failed to reject the Null hypothesis that residuals are not normally distributed
#
# So, based on given summary, Residuals are uncorrelated and Normally distributed

# %%
# Create the 4 diagostics plots for meantemp
results1.plot_diagnostics(figsize=(14,6))
plt.show()

# %%
# Create the 4 diagostics plots for humidity
results2.plot_diagnostics(figsize=(14,6))
plt.show()

# %%
# Create the 4 diagostics plots for wind speed
results3.plot_diagnostics(figsize=(14,6))
plt.show()

# %%
# Create the 4 diagostics plots for mean pressure
results4.plot_diagnostics(figsize=(14,6))
plt.show()

# %% [markdown]
# ### It is not perfect, however, our model diagnostics suggests that the model residuals are near normally distributed in all 3 cases except Mean Pressure

# %% [markdown]
# ## Predict the Values for Test set

# %%
start= len(train)
end= len(train)+len(test)-1
predictionstemp= results1.predict(start=start, end=end)
print(predictionstemp)
# Out:
# 2016-04-01    31.790748
# 2016-05-01    36.192559
# 2016-06-01    35.851191
# 2016-07-01    33.935699
# 2016-08-01    32.690046
# 2016-09-01    32.510913
# 2016-10-01    28.923849
# 2016-11-01    21.539450
# 2016-12-01    18.022199
# 2017-01-01    15.732535
# 2017-02-01    18.574801
# 2017-03-01    23.482130
# 2017-04-01    30.034596
# Freq: MS, dtype: float64

# %%
start= len(train)
end= len(train)+len(test)-1
print("Predictions on mean tempreture")
predictionstemp= results1.predict(start=start, end=end)
print(predictionstemp)
print("\n")
print("Predictions on humidity")
predictionshumidity= results2.predict(start=start, end=end)
print(predictionshumidity)
print('\n')
print("Predictions on wind speed")
predictionswindspeed= results3.predict(start=start,end=end)
print(predictionswindspeed)
print('\n')
print("Predictions on mean presure")
predictionsmeanpressure= results4.predict(start=start,end=end)
print(predictionsmeanpressure)
# Out:
# Predictions on mean tempreture
# 2016-04-01    31.790748
# 2016-05-01    36.192559
# 2016-06-01    35.851191
# 2016-07-01    33.935699
# 2016-08-01    32.690046
# 2016-09-01    32.510913
# 2016-10-01    28.923849
# 2016-11-01    21.539450
# 2016-12-01    18.022199
# 2017-01-01    15.732535
# 2017-02-01    18.574801
# 2017-03-01    23.482130
# 2017-04-01    30.034596
# Freq: MS, dtype: float64
#
#
# Predictions on humidity
# 2016-04-01    37.990020
# 2016-05-01    34.806212
# 2016-06-01    52.161911
# 2016-07-01    69.790805
# 2016-08-01    71.536216
# 2016-09-01    62.546367
# 2016-10-01    64.891691
# 2016-11-01    63.126796
# 2016-12-01    75.180005
# 2017-01-01    81.484308
# 2017-02-01    68.914106
# 2017-03-01    62.951752
# 2017-04-01    43.570342
# Freq: MS, dtype: float64
#
#
# Predictions on wind speed
# 2016-04-01    8.637566
# 2016-05-01    8.958746
# 2016-06-01    8.900182
# 2016-07-01    8.593858
# 2016-08-01    5.580543
# 2016-09-01    7.338137
# 2016-10-01    5.137493
# ...

# %%
test.plot(legend=True,figsize=(12,6))
predictionstemp.plot(label='SARIMAX',legend=True)
plt.show()

# %%
test.plot(legend=True,figsize=(12,6))
predictionshumidity.plot(label='SARIMAX',legend=True)
plt.show()

# %%
test.plot(legend=True,figsize=(12,6))
predictionsmeanpressure.plot(label='SARIMAX',legend=True)
plt.show()

# %%
test.plot(legend=True,figsize=(12,6))
predictionswindspeed.plot(label='SARIMAX',legend=True)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse

print('mean temperature:')
mse = mean_squared_error(test['meantemp'], predictionstemp)
print('Mean Squared Error ',mse)
rmse = rmse(test['meantemp'], predictionstemp)
print('Root Mean Squared Error ',rmse)
# Out:
# mean temperature:
# Mean Squared Error  1.481138987852558
# Root Mean Squared Error  1.2170205371531566

# %% [markdown]
# In statistics, the mean squared error (MSE) of an estimator measures the average of the squares of the errors — that is, the average squared difference between the estimated values and what is estimated. The MSE is a measure of the quality of an estimator — it is always non-negative, and the smaller the MSE, the closer we are to finding the line of best fit.
#
# Root Mean Square Error (RMSE) tells us that our model was able to forecast the mean temperature in the test set within 1.217 of the real sales.

# %%
##References
1) https://machinelearningmastery.com/sarima-for-time-series-forecasting-in-python/#:~:text=Define%20Model,host%20of%20model%20configuration%20parameters.&text=The%20implementation%20is%20called%20SARIMAX,implementation%20also%20supports%20exogenous%20variables.

# %%
2)https://youtu.be/2XGSIlgUBDI
3)https://youtu.be/TOeXpCHtrxk

# %%
4)https://www.kaggle.com/prasannavijayakumar/timeseries-analysis-seasonality
5)file:///C:/Users/hp/Documents/Time%20Series%20Analysis%20Books/An%20End-to-End%20Project%20on%20Time%20Series%20Analysis%20and%20Forecasting%20with%20Python.pdf
